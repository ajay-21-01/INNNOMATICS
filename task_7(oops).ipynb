# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay-21-01/INNNOMATICS/blob/main/task_7(oops).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 1: Smart Light Controller
# Create a class to control a smart light that can be turned ON or OFF and display its status.

class SmartLight:
    def __init__(self, light_name, action):
        self.light_name = light_name
        self.action = action

    def display(self):
        print(f"{self.light_name} is {self.action}")


light = SmartLight("Bedroom Light", "ON")
light.display()
# Out:
# Bedroom Light is ON

# %%
# Problem 2: Employee ID Card System
# Create a class that stores employee name, ID, and department and displays ID card details.

class EmployeeIDCard:
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department

    def display(self):
        print("Employee ID Card")
        print("Name:", self.name)
        print("ID:", self.emp_id)
        print("Department:", self.department)


emp = EmployeeIDCard("Rahul", "EMP102", "IT")
emp.display()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %%
# Problem 3: Mobile Contact Record
# Create a class to store contact name and phone number and display contact information.

class Contact:
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def display(self):
        print("Contact Saved")
        print("Name:", self.name)
        print("Phone:", self.phone)


contact = Contact("Anita", "9876543210")
contact.display()
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %%
# Problem 4: Product Price Tag Generator
# Create a class that stores product name and price and prints a formatted price tag.

class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def display(self):
        print("Product:", self.name)
        print("Price: ₹" + str(self.price))


product = Product("Headphones", 2499)
product.display()
# Out:
# Product: Headphones
# Price: ₹2499

# %%
# Problem 5: Movie Rating Display System
# Create a class that stores movie name and rating and displays movie details.

class Movie:
    def __init__(self, name, rating):
        self.name = name
        self.rating = rating

    def display(self):
        print("Movie:", self.name)
        print("Rating:", self.rating, "/ 5")


movie = Movie("Inception", 4.8)
movie.display()
# Out:
# Movie: Inception
# Rating: 4.8 / 5

# %%
# Problem 6: Delivery Address Manager
# Create a class that stores customer name and delivery address and prints delivery details.

class Delivery:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display(self):
        print("Delivery Details")
        print("Customer:", self.customer_name)
        print("Address:", self.address)


delivery = Delivery("Suman", "Hyderabad")
delivery.display()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
